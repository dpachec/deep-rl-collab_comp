# %%
from collections import deque
from unityagents import UnityEnvironment
import numpy as np
from ddpg_agent import Agent
import torch
import time
env = UnityEnvironment(file_name='Tennis')# get the default brain
brain_name = env.brain_names[0]                    # get the default brain
brain = env.brains[brain_name]
env_info = env.reset(train_mode=True)[brain_name] # reset the environment
num_agents = len(env_info.agents)
action_size = brain.vector_action_space_size
states = env_info.vector_observations              # get the current state for each agent
state_size = states.shape[1]
agent = Agent(state_size=state_size, action_size=action_size, num_agents=num_agents, random_seed=0)

def ddpg(n_episodes=1600, max_t=10000, print_every=100):
    scores_100 = deque(maxlen=print_every)
    scores_all = []
    once = True
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name] # reset the environment
        states = env_info.vector_observations              # get the current state for each agent
        scores = np.zeros(num_agents)                     # initialize the score (for each agent)
        agent.reset()
        for t in range(max_t):
            actions = agent.act(states)
            env_info = env.step(actions)[brain_name]        # send all actions to the environment
            next_states = env_info.vector_observations     # get the next state
            rewards = env_info.rewards                     # get the reward
            dones = env_info.local_done
            scores += env_info.rewards                         # update the score (for each agent)
            #print (scores)
            agent.step(states, actions, rewards, next_states, dones)
            if np.any(dones):
                #print(t)
                break 
            states = next_states
            
        #agent.learn2()
        score = np.mean(scores)
        #print (score)
        scores_100.append(score)
        scores_all.append(score)
        if np.mean(scores_100) > 0.5:
            if once:
                print('\nEnvironment solved in {:d} episodes'.format(i_episode))
                once = False
        
        if i_episode % 10 == 0:
            print('\rEpisode {}, Score last 100 episodes: {:.5f}, Score current episode: {:.5f}'\
              .format(i_episode, np.mean(scores_100), score, end="\n"))
            torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')            
            np.save('scores_all_tennis.npy', scores_all)
    return scores_all

scores = ddpg()
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: TennisBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 8
#         Number of stacked Vector Observation: 3
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 2
#         Vector Action descriptions: ,
# Episode 10, Score last 100 episodes: 0.00000, Score current episode: -0.00500
# Episode 20, Score last 100 episodes: 0.00000, Score current episode: -0.00500
# Episode 30, Score last 100 episodes: 0.00333, Score current episode: -0.00500
# Episode 40, Score last 100 episodes: 0.00250, Score current episode: -0.00500
# Episode 50, Score last 100 episodes: 0.00100, Score current episode: -0.00500
# Episode 60, Score last 100 episodes: 0.00000, Score current episode: -0.00500
# Episode 70, Score last 100 episodes: -0.00071, Score current episode: -0.00500
# Episode 80, Score last 100 episodes: -0.00125, Score current episode: -0.00500
# Episode 90, Score last 100 episodes: -0.00167, Score current episode: -0.00500
# Episode 100, Score last 100 episodes: -0.00200, Score current episode: -0.00500
# Episode 110, Score last 100 episodes: -0.00250, Score current episode: -0.00500
# Episode 120, Score last 100 episodes: -0.00300, Score current episode: -0.00500
# Episode 130, Score last 100 episodes: -0.00450, Score current episode: -0.00500
# Episode 140, Score last 100 episodes: -0.00500, Score current episode: -0.00500
# Episode 150, Score last 100 episodes: -0.00500, Score current episode: -0.00500
# Episode 160, Score last 100 episodes: -0.00500, Score current episode: -0.00500
# Episode 170, Score last 100 episodes: -0.00500, Score current episode: -0.00500
# Episode 180, Score last 100 episodes: -0.00500, Score current episode: -0.00500
# Episode 190, Score last 100 episodes: -0.00500, Score current episode: -0.00500
# Episode 200, Score last 100 episodes: -0.00500, Score current episode: -0.00500
# Episode 210, Score last 100 episodes: -0.00500, Score current episode: -0.00500
# Episode 220, Score last 100 episodes: -0.00500, Score current episode: -0.00500
# Episode 230, Score last 100 episodes: -0.00500, Score current episode: -0.00500
# Episode 240, Score last 100 episodes: -0.00500, Score current episode: -0.00500
# Episode 250, Score last 100 episodes: -0.00500, Score current episode: -0.00500
# Episode 260, Score last 100 episodes: -0.00500, Score current episode: -0.00500
# Episode 270, Score last 100 episodes: -0.00500, Score current episode: -0.00500
# Episode 280, Score last 100 episodes: -0.00500, Score current episode: -0.00500
# Episode 290, Score last 100 episodes: -0.00500, Score current episode: -0.00500
# Episode 300, Score last 100 episodes: -0.00500, Score current episode: -0.00500
# Episode 310, Score last 100 episodes: -0.00450, Score current episode: -0.00500
# Episode 320, Score last 100 episodes: -0.00400, Score current episode: -0.00500
# Episode 330, Score last 100 episodes: -0.00350, Score current episode: -0.00500
# Episode 340, Score last 100 episodes: -0.00350, Score current episode: -0.00500
# Episode 350, Score last 100 episodes: -0.00200, Score current episode: -0.00500
# Episode 360, Score last 100 episodes: -0.00200, Score current episode: -0.00500
# Episode 370, Score last 100 episodes: -0.00150, Score current episode: 0.04500
# Episode 380, Score last 100 episodes: -0.00150, Score current episode: -0.00500
# Episode 390, Score last 100 episodes: -0.00150, Score current episode: -0.00500
# Episode 400, Score last 100 episodes: -0.00150, Score current episode: -0.00500
# Episode 410, Score last 100 episodes: -0.00200, Score current episode: -0.00500
# Episode 420, Score last 100 episodes: -0.00250, Score current episode: -0.00500
# Episode 430, Score last 100 episodes: -0.00300, Score current episode: -0.00500
# Episode 440, Score last 100 episodes: -0.00300, Score current episode: -0.00500
# Episode 450, Score last 100 episodes: -0.00450, Score current episode: -0.00500
# Episode 460, Score last 100 episodes: -0.00450, Score current episode: -0.00500
# Episode 470, Score last 100 episodes: -0.00450, Score current episode: -0.00500
# Episode 480, Score last 100 episodes: -0.00300, Score current episode: -0.00500
# Episode 490, Score last 100 episodes: -0.00250, Score current episode: -0.00500
# Episode 500, Score last 100 episodes: -0.00200, Score current episode: -0.00500
# Episode 510, Score last 100 episodes: -0.00150, Score current episode: -0.00500
# Episode 520, Score last 100 episodes: -0.00150, Score current episode: -0.00500
# Episode 530, Score last 100 episodes: -0.00100, Score current episode: -0.00500
# Episode 540, Score last 100 episodes: -0.00100, Score current episode: -0.00500
# Episode 550, Score last 100 episodes: -0.00100, Score current episode: -0.00500
# Episode 560, Score last 100 episodes: -0.00100, Score current episode: -0.00500
# Episode 570, Score last 100 episodes: -0.00150, Score current episode: -0.00500
# Episode 580, Score last 100 episodes: -0.00300, Score current episode: -0.00500
# Episode 590, Score last 100 episodes: -0.00350, Score current episode: -0.00500
# Episode 600, Score last 100 episodes: -0.00400, Score current episode: -0.00500
# Episode 610, Score last 100 episodes: -0.00400, Score current episode: -0.00500
# Episode 620, Score last 100 episodes: -0.00400, Score current episode: -0.00500
# Episode 630, Score last 100 episodes: -0.00300, Score current episode: 0.09500
# Episode 640, Score last 100 episodes: -0.00150, Score current episode: -0.00500
# Episode 650, Score last 100 episodes: -0.00050, Score current episode: -0.00500
# Episode 660, Score last 100 episodes: 0.00150, Score current episode: 0.04500
# Episode 670, Score last 100 episodes: 0.00450, Score current episode: -0.00500
# Episode 680, Score last 100 episodes: 0.00650, Score current episode: -0.00500
# Episode 690, Score last 100 episodes: 0.01050, Score current episode: 0.09500
# Episode 700, Score last 100 episodes: 0.01750, Score current episode: 0.09500
# Episode 710, Score last 100 episodes: 0.02150, Score current episode: 0.04500
# Episode 720, Score last 100 episodes: 0.02650, Score current episode: 0.04500
# Episode 730, Score last 100 episodes: 0.03150, Score current episode: 0.09500
# Episode 740, Score last 100 episodes: 0.03550, Score current episode: 0.04500
# Episode 750, Score last 100 episodes: 0.04150, Score current episode: 0.09500
# Episode 760, Score last 100 episodes: 0.04495, Score current episode: -0.00500
# Episode 770, Score last 100 episodes: 0.05345, Score current episode: 0.44500
# Episode 780, Score last 100 episodes: 0.06245, Score current episode: 0.04500
# Episode 790, Score last 100 episodes: 0.06245, Score current episode: 0.04500
# Episode 800, Score last 100 episodes: 0.06295, Score current episode: 0.04500
# Episode 810, Score last 100 episodes: 0.06485, Score current episode: 0.04000
# Episode 820, Score last 100 episodes: 0.06635, Score current episode: 0.04500
# Episode 830, Score last 100 episodes: 0.06785, Score current episode: 0.09500
# Episode 840, Score last 100 episodes: 0.07385, Score current episode: 0.04500
# Episode 850, Score last 100 episodes: 0.07785, Score current episode: 0.09500
# Episode 860, Score last 100 episodes: 0.08340, Score current episode: 0.04500
# Episode 870, Score last 100 episodes: 0.08190, Score current episode: 0.04500
# Episode 880, Score last 100 episodes: 0.08190, Score current episode: 0.04500
# Episode 890, Score last 100 episodes: 0.08540, Score current episode: 0.14500
# Episode 900, Score last 100 episodes: 0.08690, Score current episode: 0.09500
# Episode 910, Score last 100 episodes: 0.09950, Score current episode: 0.14500
# Episode 920, Score last 100 episodes: 0.10800, Score current episode: -0.00500
# Episode 930, Score last 100 episodes: 0.11650, Score current episode: 0.39500
# Episode 940, Score last 100 episodes: 0.12750, Score current episode: 0.29500
# Episode 950, Score last 100 episodes: 0.13750, Score current episode: 0.89500
# Episode 960, Score last 100 episodes: 0.15605, Score current episode: -0.00500
# Episode 970, Score last 100 episodes: 0.22115, Score current episode: 0.04500
# Episode 980, Score last 100 episodes: 0.28320, Score current episode: 1.04500
# Episode 990, Score last 100 episodes: 0.35970, Score current episode: 1.29500
# Episode 1000, Score last 100 episodes: 0.41730, Score current episode: -0.00500
# Episode 1010, Score last 100 episodes: 0.46430, Score current episode: 0.39500
#
# Environment solved in 1017 episodes
# Episode 1020, Score last 100 episodes: 0.53085, Score current episode: 2.60000
# Episode 1030, Score last 100 episodes: 0.55435, Score current episode: -0.00500
# Episode 1040, Score last 100 episodes: 0.54635, Score current episode: 0.09500
# Episode 1050, Score last 100 episodes: 0.55035, Score current episode: 0.09500
# Episode 1060, Score last 100 episodes: 0.53430, Score current episode: 0.09500
# Episode 1070, Score last 100 episodes: 0.47620, Score current episode: 0.29500
# Episode 1080, Score last 100 episodes: 0.42015, Score current episode: 0.19500
# Episode 1090, Score last 100 episodes: 0.34615, Score current episode: -0.00500
# Episode 1100, Score last 100 episodes: 0.30055, Score current episode: 0.19500
# Episode 1110, Score last 100 episodes: 0.26505, Score current episode: 0.19500
# Episode 1120, Score last 100 episodes: 0.20350, Score current episode: 0.14500
# Episode 1130, Score last 100 episodes: 0.19495, Score current episode: 0.44500
# Episode 1140, Score last 100 episodes: 0.20895, Score current episode: 0.29500
# Episode 1150, Score last 100 episodes: 0.19895, Score current episode: 0.09500
# Episode 1160, Score last 100 episodes: 0.21795, Score current episode: 0.39500
# Episode 1170, Score last 100 episodes: 0.21795, Score current episode: 0.74500
# Episode 1180, Score last 100 episodes: 0.23445, Score current episode: -0.00500
# Episode 1190, Score last 100 episodes: 0.26095, Score current episode: 1.19500
# Episode 1200, Score last 100 episodes: 0.29045, Score current episode: 0.09500
# Episode 1210, Score last 100 episodes: 0.33945, Score current episode: 1.19500
# Episode 1220, Score last 100 episodes: 0.37945, Score current episode: 0.44500
# Episode 1230, Score last 100 episodes: 0.38100, Score current episode: 0.24500
# Episode 1240, Score last 100 episodes: 0.38000, Score current episode: 0.19500
# Episode 1250, Score last 100 episodes: 0.42150, Score current episode: 0.69500
# Episode 1260, Score last 100 episodes: 0.42250, Score current episode: 0.19500
# Episode 1270, Score last 100 episodes: 0.44450, Score current episode: 0.24500
# Episode 1280, Score last 100 episodes: 0.45400, Score current episode: 0.49500
# Episode 1290, Score last 100 episodes: 0.45950, Score current episode: 0.19500
# Episode 1300, Score last 100 episodes: 0.43400, Score current episode: 0.89500
# Episode 1310, Score last 100 episodes: 0.45955, Score current episode: 0.09500
# Episode 1320, Score last 100 episodes: 0.51115, Score current episode: 0.44500
# Episode 1330, Score last 100 episodes: 0.58725, Score current episode: 0.14500
# Episode 1340, Score last 100 episodes: 0.59425, Score current episode: 0.09500
# Episode 1350, Score last 100 episodes: 0.58880, Score current episode: 0.19500
# Episode 1360, Score last 100 episodes: 0.61430, Score current episode: 0.09500
# Episode 1370, Score last 100 episodes: 0.59230, Score current episode: 0.19500
# Episode 1380, Score last 100 episodes: 0.59280, Score current episode: 0.74500
# Episode 1390, Score last 100 episodes: 0.58630, Score current episode: 0.19500
# Episode 1400, Score last 100 episodes: 0.59025, Score current episode: 0.49500
# Episode 1410, Score last 100 episodes: 0.52770, Score current episode: 0.09500
# Episode 1420, Score last 100 episodes: 0.46760, Score current episode: 0.79500
# Episode 1430, Score last 100 episodes: 0.40200, Score current episode: 0.59500
# Episode 1440, Score last 100 episodes: 0.39795, Score current episode: 0.64500
# Episode 1450, Score last 100 episodes: 0.36990, Score current episode: 0.14500
# Episode 1460, Score last 100 episodes: 0.34090, Score current episode: 0.19500
# Episode 1470, Score last 100 episodes: 0.45910, Score current episode: 2.60000
# Episode 1480, Score last 100 episodes: 0.58930, Score current episode: 1.84500
# Episode 1490, Score last 100 episodes: 0.69150, Score current episode: -0.00500
# Episode 1500, Score last 100 episodes: 0.81205, Score current episode: 1.54500
# Episode 1510, Score last 100 episodes: 0.91115, Score current episode: 0.39500
# Episode 1520, Score last 100 episodes: 0.93620, Score current episode: 0.99500
# Episode 1530, Score last 100 episodes: 0.99280, Score current episode: 0.24500
# Episode 1540, Score last 100 episodes: 1.15470, Score current episode: 2.60000
# Episode 1550, Score last 100 episodes: 1.31400, Score current episode: 0.14500
# Episode 1560, Score last 100 episodes: 1.45230, Score current episode: 0.39500
# Episode 1570, Score last 100 episodes: 1.45435, Score current episode: 0.09500
# Episode 1580, Score last 100 episodes: 1.42840, Score current episode: 2.55000
# Episode 1590, Score last 100 episodes: 1.43045, Score current episode: 2.60000
# Episode 1600, Score last 100 episodes: 1.44920, Score current episode: 0.29500

# %%
## from unityagents import UnityEnvironment
import numpy as np
from ddpg_agent import Agent
import torch

env = UnityEnvironment(file_name='Tennis')# get the default brain
brain_name = env.brain_names[0]                    # get the default brain
brain = env.brains[brain_name]
env_info = env.reset(train_mode=False)[brain_name] # reset the environment
num_agents = len(env_info.agents)
action_size = brain.vector_action_space_size
states = env_info.vector_observations              # get the current state for each agent
state_size = states.shape[1]
agent = Agent(state_size=state_size, action_size=action_size, num_agents=num_agents, random_seed=0)

#load weights
agent.actor_local.load_state_dict(torch.load('checkpoint_actor.pth', map_location=lambda storage, loc: storage))
agent.critic_local.load_state_dict(torch.load('checkpoint_critic.pth', map_location=lambda storage, loc: storage))

scores = []
n_epi = 5
t_steps = 10000

for i in range (1, n_epi):
    for t in range(1, t_steps+1):
        actions = agent.act(states, False) #add noise false
        env_info = env.step(actions)[brain_name]        # send the action to the environment
        states = env_info.vector_observations    # get the next states
        dones  = env_info.local_done
        scores += env_info.rewards                         # update the score (for each agent)
        #print(scores)
        if np.any(dones):                                  # exit loop if episode finished
            break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))
env.close()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
scores = np.load('scores_all_tennis.npy')
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()

fig.tight_layout()
fig.savefig('output.png', dpi=300)
